# %% [markdown]
# <a href="https://colab.research.google.com/github/yashgupta110/RA2112701010022/blob/main/RA2112701010022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e12cd7d-5fa9-4f3b-8645-e4f8df13c62a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e12cd7d-5fa9-4f3b-8645-e4f8df13c62a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(5)
# Out:
#   Fuel Type Code  ... Restricted Access
# 0           ELEC  ...               NaN
# 1           ELEC  ...               NaN
# 2           ELEC  ...               NaN
# 3           ELEC  ...               NaN
# 4           ELEC  ...               NaN
#
# [5 rows x 65 columns]

# %%
data.tail()
# Out:
#       Fuel Type Code  ... Restricted Access
# 50284           ELEC  ...               NaN
# 50285           ELEC  ...               NaN
# 50286           ELEC  ...               NaN
# 50287           ELEC  ...               NaN
# 50288           ELEC  ...               NaN
#
# [5 rows x 65 columns]

# %%
data.shape
# Out:
# (50289, 65)

# %%
print ("number of columns" ,data.shape[0])
print ("number of Rowss" ,data.shape[1])
# Out:
# number of columns 50289
# number of Rowss 65

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50289 entries, 0 to 50288
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    50289 non-null  object
#  1   Station Name                      50289 non-null  object
#  2   Street Address                    50256 non-null  object
#  3   Intersection Directions           2491 non-null   object
#  4   City                              50289 non-null  object
#  5   State                             50289 non-null  object
#  6   ZIP                               50289 non-null  object
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     47211 non-null  object
#  9   Status Code                       50289 non-null  object
#  10  Expected Date                     147 non-null    object
# ...

# %%
data.describe(include = 'all')
# Out:
#        Fuel Type Code  ... Restricted Access
# count           50289  ...               0.0
# unique              1  ...               NaN
# top              ELEC  ...               NaN
# freq            50289  ...               NaN
# mean              NaN  ...               NaN
# std               NaN  ...               NaN
# min               NaN  ...               NaN
# 25%               NaN  ...               NaN
# 50%               NaN  ...               NaN
# 75%               NaN  ...               NaN
# max               NaN  ...               NaN
#
# [11 rows x 65 columns]

# %%
data.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
# ...

# %%
len(data[data['City'].str.contains ('Los Angeles',case=False )])
# Out:
# 1401

# %%
data.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
# ...

# %%
data[data['Station Name'].str.contains ('NaN',case=False )]
# Out:
#       Fuel Type Code  ... Restricted Access
# 67              ELEC  ...               NaN
# 115             ELEC  ...               NaN
# 190             ELEC  ...               NaN
# 191             ELEC  ...               NaN
# 517             ELEC  ...               NaN
# ...              ...  ...               ...
# 47632           ELEC  ...               NaN
# 49707           ELEC  ...               NaN
# 49708           ELEC  ...               NaN
# 50070           ELEC  ...               NaN
# 50164           ELEC  ...               NaN
#
# [144 rows x 65 columns]

# %%
len(data[data['Station Name'].str.contains ('NaN',case=False )])
# Out:
# 144

# %%
data['Station Name'].nunique()
# Out:
# 47830

# %%
data['State'].nunique()
# Out:
# 53
